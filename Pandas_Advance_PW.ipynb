# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_8016\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/57751  2172082442
# 1   https://github.com/pandas-dev/pandas/issues/57750  2172010198
# 2   https://github.com/pandas-dev/pandas/issues/57749  2171388786
# 3   https://github.com/pandas-dev/pandas/issues/57748  2171181760
# 4     https://github.com/pandas-dev/pandas/pull/57747  2170931074
# 5     https://github.com/pandas-dev/pandas/pull/57746  2170590457
# 6   https://github.com/pandas-dev/pandas/issues/57745  2170582313
# 7     https://github.com/pandas-dev/pandas/pull/57744  2170550707
# 8     https://github.com/pandas-dev/pandas/pull/57743  2170524253
# 9     https://github.com/pandas-dev/pandas/pull/57742  2170509369
# 10    https://github.com/pandas-dev/pandas/pull/57741  2170478510
# 11  https://github.com/pandas-dev/pandas/issues/57739  2170200544
# 12  https://github.com/pandas-dev/pandas/issues/57738  2169952694
# 13    https://github.com/pandas-dev/pandas/pull/57737  2169859389
# 14  https://github.com/pandas-dev/pandas/issues/57736  2169745272
# 15  https://github.com/pandas-dev/pandas/issues/57735  2169491951
# 16  https://github.com/pandas-dev/pandas/issues/57734  2169350158
# 17    https://github.com/pandas-dev/pandas/pull/57733  2168736610
# 18  https://github.com/pandas-dev/pandas/issues/57731  2168136869
# 19    https://github.com/pandas-dev/pandas/pull/57730  2168134519
# 20    https://github.com/pandas-dev/pandas/pull/57725  2167293513
# 21  https://github.com/pandas-dev/pandas/issues/57724  2167216233
# 22  https://github.com/pandas-dev/pandas/issues/57723  2167029070
# 23  https://github.com/pandas-dev/pandas/issues/57722  2166895740
# 24  https://github.com/pandas-dev/pandas/issues/57717  2166644671
# 25  https://github.com/pandas-dev/pandas/issues/57716  2165790488
# 26    https://github.com/pandas-dev/pandas/pull/57713  2165418794
# 27  https://github.com/pandas-dev/pandas/issues/57712  2165342657
# 28    https://github.com/pandas-dev/pandas/pull/57710  2165021095
# 29  https://github.com/pandas-dev/pandas/issues/57709  2165019795
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD85o3uMP   57751
# 1    I_kwDOAA0YD86Bdj7W   57750
# 2    I_kwDOAA0YD86BbMNy   57749
# 3    I_kwDOAA0YD86BaZrA   57748
# 4   PR_kwDOAA0YD85ozwqY   57747
# 5   PR_kwDOAA0YD85oym37   57746
# 6    I_kwDOAA0YD86BYHUp   57745
# 7   PR_kwDOAA0YD85oyd_K   57744
# 8   PR_kwDOAA0YD85oyYYJ   57743
# 9   PR_kwDOAA0YD85oyVOQ   57742
# 10  PR_kwDOAA0YD85oyOs0   57741
# 11   I_kwDOAA0YD86BWqHg   57739
# 12   I_kwDOAA0YD86BVtm2   57738
# 13  PR_kwDOAA0YD85owGgM   57737
# 14   I_kwDOAA0YD86BU694   57736
# 15   I_kwDOAA0YD86BT9Hv   57735
# 16   I_kwDOAA0YD86BTagO   57734
# 17  PR_kwDOAA0YD85osPCE   57733
# 18   I_kwDOAA0YD86BOySl   57731
# 19  PR_kwDOAA0YD85oqMeK   57730
# 20  PR_kwDOAA0YD85onTyj   57725
# 21   I_kwDOAA0YD86BLRhp   57724
# 22   I_kwDOAA0YD86BKj1O   57723
# 23   I_kwDOAA0YD86BKDR8   57722
# 24   I_kwDOAA0YD86BJF-_   57717
# 25   I_kwDOAA0YD86BF1cY   57716
# 26  PR_kwDOAA0YD85og6qV   57713
# 27   I_kwDOAA0YD86BEIHB   57712
# 28  PR_kwDOAA0YD85ofn8l   57710
# 29   I_kwDOAA0YD86BC5ST   57709
#
#                                                 title  ... closed_at  \
# 0        DOC: fixing GL08 errors for pandas.Series.dt  ...       NaT
# 1   BUG: .loc operation cannot locate existing ind...  ...       NaT
# 2   BUG: `Timestamp.unit` should reflect changes i...  ...       NaT
# 3   ENH: No longer always show hour, minute and se...  ...       NaT
# 4               CI: only keep conda cache for one day  ...       NaT
# 5   CLN: Enforce deprecation of groupby.idxmin/idx...  ...       NaT
# 6      DEPR: groupby.idxmin/idxmax will all NA values  ...       NaT
# 7   CLN: Enforce deprecation of groupby.quantile s...  ...       NaT
# 8   CLN: Enforce deprecation get_group with tuples...  ...       NaT
# 9   CLN: Enforce deprecation of method and limit i...  ...       NaT
# 10  CLN: Enforce deprecation of groupby with as_in...  ...       NaT
# 11      COMPAT: Utilize `copy` keyword in `__array__`  ...       NaT
# 12  BUG:  Convertion fails for columns with dateti...  ...       NaT
# 13  CI/TST: Use worksteal over loadfile for pytest...  ...       NaT
# 14                      ENH: Assign for pandas Series  ...       NaT
# 15    BUG: ValueError with loc[] = (Regression 2.1.0)  ...       NaT
# 16  QST: How to solve pandas (2.2.0) "FutureWarnin...  ...       NaT
# 17                     PERF: improve StringArray.isna  ...       NaT
# 18                   ENH: interleave_columns function  ...       NaT
# 19                Replace khash + tempita with khashl  ...       NaT
# 20              [pre-commit.ci] pre-commit autoupdate  ...       NaT
# 21       BUG: to_sql does not get the correct dialect  ...       NaT
# 22  BUG: fillna() doesn't work with `value=None` w...  ...       NaT
# 23                     DOC: SQL-style join conditions  ...       NaT
# 24  BUILD: error: metadata-generation-failed; ninj...  ...       NaT
# 25          Pandas Extension: Drop Duplicated Columns  ...       NaT
# 26          BUG: Line plots aligned from start #57594  ...       NaT
# 27          Potential regression induced by PR #57588  ...       NaT
# 28  REF: Remove dynamic docstrings from option met...  ...       NaT
# 29  BUG: Boxplot does not apply colors set by Matp...  ...       NaT
#
#    author_association active_lock_reason  draft  \
# 0                NONE                NaN    0.0
# 1                NONE                NaN    NaN
# 2         CONTRIBUTOR                NaN    NaN
# 3                NONE                NaN    NaN
# 4              MEMBER                NaN    1.0
# 5              MEMBER                NaN    0.0
# 6              MEMBER                NaN    NaN
# 7              MEMBER                NaN    0.0
# 8              MEMBER                NaN    0.0
# 9              MEMBER                NaN    0.0
# 10             MEMBER                NaN    0.0
# 11             MEMBER                NaN    NaN
# 12               NONE                NaN    NaN
# 13             MEMBER                NaN    0.0
# 14               NONE                NaN    NaN
# 15        CONTRIBUTOR                NaN    NaN
# 16               NONE                NaN    NaN
# 17             MEMBER                NaN    0.0
# 18        CONTRIBUTOR                NaN    NaN
# 19             MEMBER                NaN    1.0
# 20        CONTRIBUTOR                NaN    0.0
# 21               NONE                NaN    NaN
# 22        CONTRIBUTOR                NaN    NaN
# 23               NONE                NaN    NaN
# 24               NONE                NaN    NaN
# 25               NONE                NaN    NaN
# 26               NONE                NaN    0.0
# 27             MEMBER                NaN    NaN
# 28             MEMBER                NaN    0.0
# 29               NONE                NaN    NaN
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6                                                 NaN
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18                                                NaN
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29                                                NaN
#
#                                                  body  \
# 0   Resolved GL08 error for `scripts/validate_docs...
# 1   ### Pandas version checks\r\n\r\n- [X] I have ...
# 2   ### Pandas version checks\n\n- [X] I have chec...
# 3   ### Feature Type\n\n- [ ] Adding new functiona...
# 4   Our conda envs are being cached, but that also...
# 5   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 6   #54234 deprecated the case of `skipna=False` a...
# 7   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 8   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 9   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 10  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 11  https://github.com/pandas-dev/pandas/pull/5717...
# 12  ### Pandas version checks\n\n- [X] I have chec...
# 13  In theory, this should help alleviate a worker...
# 14  ### Feature Type\r\n\r\n- [X] Adding new funct...
# 15  ### Pandas version checks\n\n- [X] I have chec...
# 16  ### Research\n\n- [X] I have searched the [[pa...
# 17  See https://github.com/pandas-dev/pandas/issue...
# 18  ### Feature Type\n\n- [x] Adding new functiona...
# 19  supersedes #56432\r\n\r\nthis is just a resear...
# 20  <!--pre-commit.ci start-->\nupdates:\n- [githu...
# 21  ### Pandas version checks\n\n- [X] I have chec...
# 22  ### Pandas version checks\n\n- [X] I have chec...
# 23  ### Pandas version checks\n\n- [X] I have chec...
# 24  ### Installation check\n\n- [X] I have read th...
# 25  ### Feature Type\n\n- [X] Adding new functiona...
# 26  #57594 BUG: df.plot makes a shift to the right...
# 27  \r\nPR #57588\r\n\r\nIf this is expected pleas...
# 28  xref https://github.com/pandas-dev/pandas/issu...
# 29  ### Pandas version checks\n\n- [X] I have chec...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       NaN          NaN
# 5                       NaN          NaN
# 6                       NaN          NaN
# 7                       NaN          NaN
# 8                       NaN          NaN
# 9                       NaN          NaN
# 10                      NaN          NaN
# 11                      NaN          NaN
# 12                      NaN          NaN
# 13                      NaN          NaN
# 14                      NaN          NaN
# 15                      NaN          NaN
# 16                      NaN          NaN
# 17                      NaN          NaN
# 18                      NaN          NaN
# 19                      NaN          NaN
# 20                      NaN          NaN
# 21                      NaN          NaN
# 22                      NaN          NaN
# 23                      NaN          NaN
# 24                      NaN          NaN
# 25                      NaN          NaN
# 26                      NaN          NaN
# 27                      NaN          NaN
# 28                      NaN          NaN
# 29                      NaN          NaN
#
# [30 rows x 30 columns]

# %%
import requests
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
df = data.json()
df
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57751',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57751/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57751/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57751/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57751',
#   'id': 2172082442,
#   'node_id': 'PR_kwDOAA0YD85o3uMP',
#   'number': 57751,
#   'title': 'DOC: fixing GL08 errors for pandas.Series.dt',
#   'user': {'login': 's1099',
#    'id': 46890315,
#    'node_id': 'MDQ6VXNlcjQ2ODkwMzE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46890315?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/s1099',
#    'html_url': 'https://github.com/s1099',
#    'followers_url': 'https://api.github.com/users/s1099/followers',
#    'following_url': 'https://api.github.com/users/s1099/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/s1099/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/s1099/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/s1099/subscriptions',
#    'organizations_url': 'https://api.github.com/users/s1099/orgs',
#    'repos_url': 'https://api.github.com/users/s1099/repos',
#    'events_url': 'https://api.github.com/users/s1099/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/s1099/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-03-06T17:40:16Z',
#   'updated_at': '2024-03-06T18:10:21Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57751',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57751',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57751.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57751.patch',
#    'merged_at': None},
#   'body': 'Resolved GL08 error for `scripts/validate_docstrings.py --format=actions --errors=GL08 pandas.Series.dt`\r\nxref: #57443\r\n\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57751/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57751/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57750',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57750/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57750/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57750/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57750',
#   'id': 2172010198,
#   'node_id': 'I_kwDOAA0YD86Bdj7W',
#   'number': 57750,
#   'title': "BUG: .loc operation cannot locate existing index when having single string as index for dataframe ('string',)",
#   'user': {'login': 'carlonlv',
#    'id': 36804238,
#    'node_id': 'MDQ6VXNlcjM2ODA0MjM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36804238?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/carlonlv',
#    'html_url': 'https://github.com/carlonlv',
#    'followers_url': 'https://api.github.com/users/carlonlv/followers',
#    'following_url': 'https://api.github.com/users/carlonlv/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/carlonlv/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/carlonlv/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/carlonlv/subscriptions',
#    'organizations_url': 'https://api.github.com/users/carlonlv/orgs',
#    'repos_url': 'https://api.github.com/users/carlonlv/repos',
#    'events_url': 'https://api.github.com/users/carlonlv/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/carlonlv/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-03-06T16:59:06Z',
#   'updated_at': '2024-03-06T17:02:51Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\ntemp = pd.DataFrame({\'a\': [1,2,3], \'b\': False}, index=[(\'h\',), (\'v\',), (\'c\',)])\r\nprint((\'h\',) in temp.index) ## This would print True\r\ntemp.loc[(\'h\',), \'b\'] = True ## This would result in key error\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nIt seems like when having indices looking at (\'a\',), pandas automatically converts it into string \'a\'. \r\n\r\nKeyError: "None of [Index([\'h\'], dtype=\'object\')] are in the [index]"\r\n\r\n### Expected Behavior\r\n\r\ntemp.loc[(\'h\',)] operation should be successful\r\n\r\n### Installed Versions\r\n\r\n<details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : bdc79c146c2e32f2cab629be240f01658cfb6cc2\r\npython                : 3.11.5.final.0\r\npython-bits           : 64\r\nOS                    : Linux\r\nOS-release            : 6.5.0-1015-azure\r\nVersion               : #15~22.04.1-Ubuntu SMP Tue Feb 13 01:15:12 UTC 2024\r\nmachine               : x86_64\r\nprocessor             : x86_64\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : C.UTF-8\r\nLOCALE                : en_US.UTF-8\r\n\r\npandas                : 2.2.1\r\nnumpy                 : 1.26.3\r\npytz                  : 2023.3.post1\r\ndateutil              : 2.8.2\r\nsetuptools            : 68.2.2\r\npip                   : 23.3.1\r\nCython                : None\r\npytest                : None\r\nhypothesis            : None\r\nsphinx                : None\r\nblosc                 : None\r\nfeather               : None\r\nxlsxwriter            : None\r\nlxml.etree            : None\r\nhtml5lib              : None\r\npymysql               : None\r\npsycopg2              : None\r\njinja2                : 3.1.3\r\nIPython               : 8.20.0\r\npandas_datareader     : None\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : None\r\nbottleneck            : 1.3.7\r\ndataframe-api-compat  : None\r\nfastparquet           : None\r\nfsspec                : 2023.12.2\r\ngcsfs                 : None\r\nmatplotlib            : 3.8.3\r\nnumba                 : None\r\nnumexpr               : 2.8.7\r\nodfpy                 : None\r\nopenpyxl              : None\r\npandas_gbq            : None\r\npyarrow               : None\r\npyreadstat            : None\r\npython-calamine       : None\r\npyxlsb                : None\r\ns3fs                  : None\r\nscipy                 : None\r\nsqlalchemy            : None\r\ntables                : None\r\ntabulate              : None\r\nxarray                : None\r\nxlrd                  : None\r\nzstandard             : 0.19.0\r\ntzdata                : 2023.3\r\nqtpy                  : None\r\npyqt5                 : None\r\n</details>',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57750/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57750/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57749',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57749/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57749/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57749/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57749',
#   'id': 2171388786,
#   'node_id': 'I_kwDOAA0YD86BbMNy',
#   'number': 57749,
#   'title': 'BUG: `Timestamp.unit` should reflect changes in components after `Timestamp.replace`',
#   'user': {'login': 'wjsi',
#    'id': 8284922,
#    'node_id': 'MDQ6VXNlcjgyODQ5MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8284922?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wjsi',
#    'html_url': 'https://github.com/wjsi',
#    'followers_url': 'https://api.github.com/users/wjsi/followers',
#    'following_url': 'https://api.github.com/users/wjsi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/wjsi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/wjsi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/wjsi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/wjsi/orgs',
#    'repos_url': 'https://api.github.com/users/wjsi/repos',
#    'events_url': 'https://api.github.com/users/wjsi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/wjsi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 3713792788,
#     'node_id': 'LA_kwDOAA0YD87dW_sU',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Non-Nano',
#     'name': 'Non-Nano',
#     'color': '006b75',
#     'default': False,
#     'description': 'datetime64/timedelta64 with non-nanosecond resolution'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-03-06T12:26:27Z',
#   'updated_at': '2024-03-06T17:43:08Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport datetime\r\nimport pandas as pd\r\n\r\nts = pd.Timestamp("2023-07-15 23:08:12.134567123")\r\nprint(ts)  # shows Timestamp(\'2023-07-16 23:08:12.134567123\')\r\nts2 = pd.Timestamp(datetime.datetime.utcfromtimestamp(int(ts.timestamp())))\r\nts2 = ts2.replace(microsecond=ts.microsecond, nanosecond=ts.nanosecond)\r\nprint(ts2)  # shows Timestamp(\'2023-07-16 23:08:12.134567123\')\r\nassert ts == ts2  # fails\n```\n\n\n### Issue Description\n\nWhile repr(ts) and repr(ts2) are equal, direct comparison fails.\n\n### Expected Behavior\n\nts and ts2 shall be equal.\n\n### Installed Versions\n\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : bdc79c146c2e32f2cab629be240f01658cfb6cc2\r\npython                : 3.9.16.final.0\r\npython-bits           : 64\r\nOS                    : Darwin\r\nOS-release            : 22.5.0\r\nVersion               : Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:22 PDT 2023; root:xnu-8796.121.3~7/RELEASE_X86_64\r\nmachine               : x86_64\r\nprocessor             : i386\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : zh_CN.UTF-8\r\nLOCALE                : zh_CN.UTF-8\r\n\r\npandas                : 2.2.1\r\nnumpy                 : 1.25.2\r\npytz                  : 2023.3.post1\r\ndateutil              : 2.8.2\r\nsetuptools            : 61.2.0\r\npip                   : 22.3.1\r\nCython                : 3.0.2\r\npytest                : 8.0.2\r\nhypothesis            : 6.46.5\r\nsphinx                : 7.2.6\r\nblosc                 : None\r\nfeather               : None\r\nxlsxwriter            : None\r\nlxml.etree            : None\r\nhtml5lib              : None\r\npymysql               : None\r\npsycopg2              : None\r\njinja2                : None\r\nIPython               : 8.1.1\r\npandas_datareader     : None\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : None\r\nbottleneck            : 1.3.8\r\ndataframe-api-compat  : None\r\nfastparquet           : None\r\nfsspec                : None\r\ngcsfs                 : None\r\nmatplotlib            : 3.7.2\r\nnumba                 : None\r\nnumexpr               : 2.8.4\r\nodfpy                 : None\r\nopenpyxl              : 3.1.2\r\npandas_gbq            : None\r\npyarrow               : 11.0.0\r\npyreadstat            : None\r\npython-calamine       : None\r\npyxlsb                : None\r\ns3fs                  : None\r\nscipy                 : 1.11.1\r\nsqlalchemy            : 2.0.19\r\ntables                : None\r\ntabulate              : None\r\nxarray                : None\r\nxlrd                  : None\r\nzstandard             : 0.21.0\r\ntzdata                : 2023.3\r\nqtpy                  : None\r\npyqt5                 : None',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57749/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57749/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57748',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57748/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57748/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57748/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57748',
#   'id': 2171181760,
#   'node_id': 'I_kwDOAA0YD86BaZrA',
#   'number': 57748,
#   'title': 'ENH: No longer always show hour, minute and second components for pd.Interval ',
#   'user': {'login': 'ClaireDons',
#    'id': 82878115,
#    'node_id': 'MDQ6VXNlcjgyODc4MTE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82878115?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ClaireDons',
#    'html_url': 'https://github.com/ClaireDons',
#    'followers_url': 'https://api.github.com/users/ClaireDons/followers',
#    'following_url': 'https://api.github.com/users/ClaireDons/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ClaireDons/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ClaireDons/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ClaireDons/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ClaireDons/orgs',
#    'repos_url': 'https://api.github.com/users/ClaireDons/repos',
#    'events_url': 'https://api.github.com/users/ClaireDons/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ClaireDons/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-03-06T10:39:28Z',
#   'updated_at': '2024-03-06T13:30:54Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Feature Type\n\n- [ ] Adding new functionality to pandas\n\n- [X] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\n`pd.Interval` behaviour change from #55035 means that hour, minute and second components is always shown regardless of if timezone is included as an argument. The default behaviour until now has been for time to be dropped if 00:00:00. In our use-case this broke some tests and does not provide useful information. \r\n\r\n```\r\n  -    anchor_year  i_interval                  interval   data  is_target\r\n    -0          2019          -1  [2019-07-04, 2019-12-31)   14.5      False\r\n    -1          2019           1  [2019-12-31, 2020-06-28)  119.5       True\r\n    -2          2020          -1  [2020-07-04, 2020-12-31)  305.5      False\r\n    -3          2020           1  [2020-12-31, 2021-06-29)  485.5       True\r\n    +   anchor_year  i_interval                                    interval   data  is_target\r\n    +0         2019          -1  [2019-07-04 00:00:00, 2019-12-31 00:00:00)   14.5      False\r\n    +1         2019           1  [2019-12-31 00:00:00, 2020-06-28 00:00:00)  119.5       True\r\n    +2         2020          -1  [2020-07-04 00:00:00, 2020-12-31 00:00:00)  305.5      False\r\n    +3         2020           1  [2020-12-31 00:00:00, 2021-06-29 00:00:00)  485.5       True\r\n```\n\n### Feature Description\n\nIt would be nice to revert to dropping hour, minute and second components when 00:00:00 and when no timezone is specified. \n\n### Alternative Solutions\n\nN/A\n\n### Additional Context\n\n_No response_',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57748/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57748/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57747',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57747/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57747/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57747/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57747',
#   'id': 2170931074,
#   'node_id': 'PR_kwDOAA0YD85ozwqY',
#   'number': 57747,
#   'title': 'CI: only keep conda cache for one day',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-03-06T08:35:21Z',
#   'updated_at': '2024-03-06T17:04:26Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57747',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57747',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57747.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57747.patch',
#    'merged_at': None},
#   'body': "Our conda envs are being cached, but that also means that for the dev builds (eg numpy nightly, pyarrow nightly), you don't actually get the latest version, depending on whether some other change happened in the CI setup that would invalidate the cache.\r\n\r\nMaybe ideally we do this _only_ for those builds that test for other dev packages? \r\n\r\nFrom https://github.com/mamba-org/setup-micromamba?tab=readme-ov-file#caching  \r\nRelated issue: https://github.com/mamba-org/setup-micromamba/issues/50",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57747/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57747/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57746',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57746/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57746/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57746/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57746',
#   'id': 2170590457,
#   'node_id': 'PR_kwDOAA0YD85oym37',
#   'number': 57746,
#   'title': 'CLN: Enforce deprecation of groupby.idxmin/idxmax with skipna=False not raising',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 2822342,
#     'node_id': 'MDU6TGFiZWwyODIyMzQy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data',
#     'name': 'Missing-data',
#     'color': 'd7e102',
#     'default': False,
#     'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None},
#    {'id': 2365504383,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0Mzgz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reduction%20Operations',
#     'name': 'Reduction Operations',
#     'color': '547c03',
#     'default': False,
#     'description': 'sum, mean, min, max, etc.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/102',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels',
#    'id': 9021906,
#    'node_id': 'MI_kwDOAA0YD84AianS',
#    'number': 102,
#    'title': '3.0',
#    'description': '',
#    'creator': {'login': 'jbrockmendel',
#     'id': 8078968,
#     'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jbrockmendel',
#     'html_url': 'https://github.com/jbrockmendel',
#     'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#     'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#     'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#     'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 55,
#    'closed_issues': 352,
#    'state': 'open',
#    'created_at': '2023-02-08T18:16:49Z',
#    'updated_at': '2024-03-06T07:32:45Z',
#    'due_on': '2024-04-01T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-03-06T04:01:24Z',
#   'updated_at': '2024-03-06T04:01:25Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57746',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57746',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57746.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57746.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nRef: #54234 ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57746/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57746/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57745',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57745/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57745/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57745/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57745',
#   'id': 2170582313,
#   'node_id': 'I_kwDOAA0YD86BYHUp',
#   'number': 57745,
#   'title': 'DEPR: groupby.idxmin/idxmax will all NA values',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 2822342,
#     'node_id': 'MDU6TGFiZWwyODIyMzQy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data',
#     'name': 'Missing-data',
#     'color': 'd7e102',
#     'default': False,
#     'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'},
#    {'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'},
#    {'id': 2365504383,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0Mzgz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reduction%20Operations',
#     'name': 'Reduction Operations',
#     'color': '547c03',
#     'default': False,
#     'description': 'sum, mean, min, max, etc.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/115',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/115',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/115/labels',
#    'id': 10357884,
#    'node_id': 'MI_kwDOAA0YD84Angx8',
#    'number': 115,
#    'title': '4.0',
#    'description': None,
#    'creator': {'login': 'lithomas1',
#     'id': 47963215,
#     'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/lithomas1',
#     'html_url': 'https://github.com/lithomas1',
#     'followers_url': 'https://api.github.com/users/lithomas1/followers',
#     'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#     'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#     'repos_url': 'https://api.github.com/users/lithomas1/repos',
#     'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 2,
#    'closed_issues': 0,
#    'state': 'open',
#    'created_at': '2023-12-29T18:11:43Z',
#    'updated_at': '2024-03-06T03:50:28Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-03-06T03:50:28Z',
#   'updated_at': '2024-03-06T03:50:29Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '#54234 deprecated the case of `skipna=False` and any NA value, but for consistency with Series/DataFrame versions, we also want the case of `skipna=True` with all NA values in a group to also raise. E.g. this should raise a ValueError\r\n\r\n```\r\ndf = pd.DataFrame({\'a\': [1, 1, 2], \'b\': np.nan})\r\ngb = df.groupby("a")\r\nprint(gb.idxmin())\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57745/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57745/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57744',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57744/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57744/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57744/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57744',
#   'id': 2170550707,
#   'node_id': 'PR_kwDOAA0YD85oyd_K',
#   'number': 57744,
#   'title': 'CLN: Enforce deprecation of groupby.quantile supporting bool dtype',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None},
#    {'id': 1631984902,
#     'node_id': 'MDU6TGFiZWwxNjMxOTg0OTAy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/quantile',
#     'name': 'quantile',
#     'color': '006b75',
#     'default': False,
#     'description': 'quantile method'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/102',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels',
#    'id': 9021906,
#    'node_id': 'MI_kwDOAA0YD84AianS',
#    'number': 102,
#    'title': '3.0',
#    'description': '',
#    'creator': {'login': 'jbrockmendel',
#     'id': 8078968,
#     'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jbrockmendel',
#     'html_url': 'https://github.com/jbrockmendel',
#     'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#     'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#     'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#     'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 55,
#    'closed_issues': 352,
#    'state': 'open',
#    'created_at': '2023-02-08T18:16:49Z',
#    'updated_at': '2024-03-06T07:32:45Z',
#    'due_on': '2024-04-01T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-03-06T03:28:08Z',
#   'updated_at': '2024-03-06T15:05:11Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57744',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57744',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57744.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57744.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nRef: #53975',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57744/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57744/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57743',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57743/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57743/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57743/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57743',
#   'id': 2170524253,
#   'node_id': 'PR_kwDOAA0YD85oyYYJ',
#   'number': 57743,
#   'title': 'CLN: Enforce deprecation get_group with tuples of length 1',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/102',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels',
#    'id': 9021906,
#    'node_id': 'MI_kwDOAA0YD84AianS',
#    'number': 102,
#    'title': '3.0',
#    'description': '',
#    'creator': {'login': 'jbrockmendel',
#     'id': 8078968,
#     'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jbrockmendel',
#     'html_url': 'https://github.com/jbrockmendel',
#     'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#     'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#     'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#     'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 55,
#    'closed_issues': 352,
#    'state': 'open',
#    'created_at': '2023-02-08T18:16:49Z',
#    'updated_at': '2024-03-06T07:32:45Z',
#    'due_on': '2024-04-01T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-03-06T02:55:35Z',
#   'updated_at': '2024-03-06T03:17:35Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57743',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57743',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57743.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57743.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nRef: #54155',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57743/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57743/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57742',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57742/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57742/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57742/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57742',
#   'id': 2170509369,
#   'node_id': 'PR_kwDOAA0YD85oyVOQ',
#   'number': 57742,
#   'title': 'CLN: Enforce deprecation of method and limit in pct_change methods',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2822342,
#     'node_id': 'MDU6TGFiZWwyODIyMzQy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data',
#     'name': 'Missing-data',
#     'color': 'd7e102',
#     'default': False,
#     'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'},
#    {'id': 211029535,
# ...
#   'labels': [{'id': 2413328,
#     'node_id': 'MDU6TGFiZWwyNDEzMzI4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Visualization',
#     'name': 'Visualization',
#     'color': '8AE234',
#     'default': False,
#     'description': 'plotting'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-03-03T15:34:23Z',
#   'updated_at': '2024-03-05T19:04:56Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57713',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57713',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57713.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57713.patch',
#    'merged_at': None},
#   'body': '#57594 BUG: df.plot makes a shift to the right if frequency multiplies to n > 1\r\n\r\nThe cause of this bug is that by default all elements are generated to align to the end of\r\na period instead of at the start and the period technically does not end at the start of\r\nthe last period but rather just before the period subsequent to the last period. To fix this\r\nproblem we therefore passed a parameter stating that the elements should be aligned to\r\nthe start of the period instead of the end. Parameter "how=S" was added in pandas/plotting/_matplotlib/timeseries.py::maybe_convert_index(), \r\non the function call data.index.asfreq(freq=freq_str, how = "S").  \r\n\r\nAdditional tests were added to test whether input data match data in plot and one test was merged into one the added test to reduce code duplication. ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57713/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57713/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57712',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57712/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57712/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57712/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57712',
#   'id': 2165342657,
#   'node_id': 'I_kwDOAA0YD86BEIHB',
#   'number': 57712,
#   'title': 'Potential regression induced by PR #57588',
#   'user': {'login': 'DeaMariaLeon',
#    'id': 11835246,
#    'node_id': 'MDQ6VXNlcjExODM1MjQ2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11835246?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DeaMariaLeon',
#    'html_url': 'https://github.com/DeaMariaLeon',
#    'followers_url': 'https://api.github.com/users/DeaMariaLeon/followers',
#    'following_url': 'https://api.github.com/users/DeaMariaLeon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DeaMariaLeon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DeaMariaLeon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DeaMariaLeon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DeaMariaLeon/orgs',
#    'repos_url': 'https://api.github.com/users/DeaMariaLeon/repos',
#    'events_url': 'https://api.github.com/users/DeaMariaLeon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DeaMariaLeon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 732775912,
#     'node_id': 'MDU6TGFiZWw3MzI3NzU5MTI=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Benchmark',
#     'name': 'Benchmark',
#     'color': 'ae68cc',
#     'default': False,
#     'description': 'Performance (ASV) benchmarks'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-03-03T12:50:21Z',
#   'updated_at': '2024-03-03T19:29:40Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "\r\nPR #57588\r\n\r\nIf this is expected please ignore this issue. \r\n\r\nThe largest regressions seem to be the benchmarks bellow. \r\nedit: the names of all the benchmarks with links to their plot are in the attached file.\r\n\r\n`series_methods.Dropna.time_dropna` (Python) with dtype='datetime'\r\n`groupby.GroupByMethods.time_dtype_as_field` (Python) with application='direct', dtype='int16', method='head', ncols=1, param5='cython'\r\n`groupby.Nth.time_series_nth_all` (Python) with dtype='datetime'\r\n\r\n@mroeschke\r\n\r\n[cleaned_regression_file.json](https://github.com/pandas-dev/pandas/files/14473488/cleaned_regression_file.json)\r\n\r\n\r\n![Screenshot 2024-03-03 at 13 26 15](https://github.com/pandas-dev/pandas/assets/11835246/8f8432af-42b5-42e4-827e-a8805bd28e59)\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57712/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57712/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57710',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57710/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57710/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57710/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57710',
#   'id': 2165021095,
#   'node_id': 'PR_kwDOAA0YD85ofn8l',
#   'number': 57710,
#   'title': 'REF: Remove dynamic docstrings from option methods',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127681,
#     'node_id': 'MDU6TGFiZWwxMjc2ODE=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#     'name': 'Refactor',
#     'color': 'FCE94F',
#     'default': False,
#     'description': 'Internal refactoring of code'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-03-02T23:09:36Z',
#   'updated_at': '2024-03-06T00:10:11Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57710',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57710',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57710.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57710.patch',
#    'merged_at': None},
#   'body': "xref https://github.com/pandas-dev/pandas/issues/57578#issuecomment-1960937283\r\n\r\nThese methods have complex docstrings in an attempt to display all option within the docstring. This makes these docstrings hard to automatically validate and [renders the internal implementation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.describe_option.html#pandas.describe_option) in Sphinx. I think it's reasonable to link to the docs where all the options are listed instead.\r\n\r\nAdditionally did some cleanups removing `silent` from some of these methods by instead catching warnings where needed\r\n\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57710/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57710/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57709',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57709/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57709/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57709/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57709',
#   'id': 2165019795,
#   'node_id': 'I_kwDOAA0YD86BC5ST',
#   'number': 57709,
#   'title': 'BUG: Boxplot does not apply colors set by Matplotlib rcParams for certain plot elements',
#   'user': {'login': 'thetestspecimen',
#    'id': 40262729,
#    'node_id': 'MDQ6VXNlcjQwMjYyNzI5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40262729?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thetestspecimen',
#    'html_url': 'https://github.com/thetestspecimen',
#    'followers_url': 'https://api.github.com/users/thetestspecimen/followers',
#    'following_url': 'https://api.github.com/users/thetestspecimen/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/thetestspecimen/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/thetestspecimen/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/thetestspecimen/subscriptions',
#    'organizations_url': 'https://api.github.com/users/thetestspecimen/orgs',
#    'repos_url': 'https://api.github.com/users/thetestspecimen/repos',
#    'events_url': 'https://api.github.com/users/thetestspecimen/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/thetestspecimen/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-03-02T23:04:34Z',
#   'updated_at': '2024-03-02T23:18:30Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport numpy as np\r\nimport pandas as pd\r\nimport matplotlib.pyplot as plt\r\nimport matplotlib as mpl\r\ndf = pd.DataFrame(np.random.default_rng(12).random((10, 2)))\r\nwith mpl.rc_context({\'boxplot.boxprops.color\': \'red\',\r\n                     \'boxplot.whiskerprops.color\': \'green\',\r\n                     \'boxplot.capprops.color\': \'orange\',\r\n                     \'boxplot.medianprops.color\': \'cyan\',\r\n                     \'patch.facecolor\': \'grey\'}):\r\n    df.plot.box(patch_artist=True) # OR df.plot(kind=\'box\', patch_artist=True)\r\n    plt.show()\n```\n\n\n### Issue Description\n\nIf the \'Reproducible Example\' code is run it will result in the following:\r\n\r\n![pandas-example](https://github.com/pandas-dev/pandas/assets/40262729/f37f4507-2715-4962-b4ec-d9446014093d)\r\n\r\nIf run directly through Matplotlib like so:\r\n\r\n```python\r\nimport numpy as np\r\nimport pandas as pd\r\nimport matplotlib.pyplot as plt\r\nimport matplotlib as mpl\r\ndf = pd.DataFrame(np.random.default_rng(12).random((10, 2)))\r\nwith mpl.rc_context({\'boxplot.boxprops.color\': \'red\',\r\n                     \'boxplot.whiskerprops.color\': \'green\',\r\n                     \'boxplot.capprops.color\': \'orange\',\r\n                     \'boxplot.medianprops.color\': \'cyan\',\r\n                     \'patch.facecolor\': \'grey\'}):\r\n    plt.boxplot(df, patch_artist=True)\r\n    plt.show()\r\n```\r\nYou end up with this:\r\n\r\n![matplotlib-example](https://github.com/pandas-dev/pandas/assets/40262729/6f456b59-b8f9-48b1-b008-46091291660d)\r\n\r\nAs you can see Pandas completely ignores the rcParams assignment, and sets it\'s own colours. \r\n\r\nI have only included in this example the exact elements (box, whiskers, caps, medians and box-face) that are ignored. It should also be noted that as the rcParams are ignored, Matplotlib stylesheets are also ignored if applied to these elements.\r\n\r\nAs Pandas does this **only** for these specific elements in the boxplot, it can result in some terrible looking plots if someone uses a comprehensive set of rcParams (or stylesheet) that have a significantly different set of colours.\r\n\r\n### A solution?\r\n\r\nI have looked into where this occurs, and all the relevant code resides in:\r\n\r\nhttps://github.com/pandas-dev/pandas/blob/main/pandas/plotting/_matplotlib/boxplot.py\r\n\r\nSpecifically, methods `_get_colors()`  and `_color_attrs(self)`. These two methods (among other bits of linked code) basically pick specific colours from the assigned colormap and apply them to the plot.\r\n\r\nI know what needs adjusting, and could put in a PR. However, due to the nature of rcParams being the "default" and hence having the lowest priority in terms of application, I see no way to adjust the code without changing the current default colours (i.e. blue, and a green median taken from the "tab10" colormap). \r\n\r\nThat is why I am filing this \'bug\', as I can see this change might be objectionable, and as such will require further discussion on the appropriate solution. The solution I am proposing, of using matplotlib rcParam defaults, would result in the following "default" plot:\r\n\r\n![matplotlib-default](https://github.com/pandas-dev/pandas/assets/40262729/6d2af3ab-a99d-459c-84d5-1e072d2b8d94)\r\n\r\nMy personal opinion is that this visual change is minor, and therefore should be implemented. I would also argue that accessibility is hindered by the current implementation (colour blindness being an example). \r\n\r\n# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57709/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57709/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
for i in range(len(df)):
    print(df[i])
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57751', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57751/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57751/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57751/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57751', 'id': 2172082442, 'node_id': 'PR_kwDOAA0YD85o3uMP', 'number': 57751, 'title': 'DOC: fixing GL08 errors for pandas.Series.dt', 'user': {'login': 's1099', 'id': 46890315, 'node_id': 'MDQ6VXNlcjQ2ODkwMzE1', 'avatar_url': 'https://avatars.githubusercontent.com/u/46890315?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/s1099', 'html_url': 'https://github.com/s1099', 'followers_url': 'https://api.github.com/users/s1099/followers', 'following_url': 'https://api.github.com/users/s1099/following{/other_user}', 'gists_url': 'https://api.github.com/users/s1099/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/s1099/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/s1099/subscriptions', 'organizations_url': 'https://api.github.com/users/s1099/orgs', 'repos_url': 'https://api.github.com/users/s1099/repos', 'events_url': 'https://api.github.com/users/s1099/events{/privacy}', 'received_events_url': 'https://api.github.com/users/s1099/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2024-03-06T17:40:16Z', 'updated_at': '2024-03-06T18:10:21Z', 'closed_at': None, 'author_association': 'NONE', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57751', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57751', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57751.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57751.patch', 'merged_at': None}, 'body': 'Resolved GL08 error for `scripts/validate_docstrings.py --format=actions --errors=GL08 pandas.Series.dt`\r\nxref: #57443\r\n\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n', 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57751/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57751/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57750', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57750/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57750/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57750/events', 'html_url': 'https://github.com/pandas-dev/pandas/issues/57750', 'id': 2172010198, 'node_id': 'I_kwDOAA0YD86Bdj7W', 'number': 57750, 'title': "BUG: .loc operation cannot locate existing index when having single string as index for dataframe ('string',)", 'user': {'login': 'carlonlv', 'id': 36804238, 'node_id': 'MDQ6VXNlcjM2ODA0MjM4', 'avatar_url': 'https://avatars.githubusercontent.com/u/36804238?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/carlonlv', 'html_url': 'https://github.com/carlonlv', 'followers_url': 'https://api.github.com/users/carlonlv/followers', 'following_url': 'https://api.github.com/users/carlonlv/following{/other_user}', 'gists_url': 'https://api.github.com/users/carlonlv/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/carlonlv/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/carlonlv/subscriptions', 'organizations_url': 'https://api.github.com/users/carlonlv/orgs', 'repos_url': 'https://api.github.com/users/carlonlv/repos', 'events_url': 'https://api.github.com/users/carlonlv/events{/privacy}', 'received_events_url': 'https://api.github.com/users/carlonlv/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug', 'name': 'Bug', 'color': 'e10c02', 'default': False, 'description': None}, {'id': 1954720290, 'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage', 'name': 'Needs Triage', 'color': '0052cc', 'default': False, 'description': 'Issue that has not been reviewed by a pandas team member'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2024-03-06T16:59:06Z', 'updated_at': '2024-03-06T17:02:51Z', 'closed_at': None, 'author_association': 'NONE', 'active_lock_reason': None, 'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\ntemp = pd.DataFrame({\'a\': [1,2,3], \'b\': False}, index=[(\'h\',), (\'v\',), (\'c\',)])\r\nprint((\'h\',) in temp.index) ## This would print True\r\ntemp.loc[(\'h\',), \'b\'] = True ## This would result in key error\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nIt seems like when having indices looking at (\'a\',), pandas automatically converts it into string \'a\'. \r\n\r\nKeyError: "None of [Index([\'h\'], dtype=\'object\')] are in the [index]"\r\n\r\n### Expected Behavior\r\n\r\ntemp.loc[(\'h\',)] operation should be successful\r\n\r\n### Installed Versions\r\n\r\n<details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : bdc79c146c2e32f2cab629be240f01658cfb6cc2\r\npython                : 3.11.5.final.0\r\npython-bits           : 64\r\nOS                    : Linux\r\nOS-release            : 6.5.0-1015-azure\r\nVersion               : #15~22.04.1-Ubuntu SMP Tue Feb 13 01:15:12 UTC 2024\r\nmachine               : x86_64\r\nprocessor             : x86_64\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : C.UTF-8\r\nLOCALE                : en_US.UTF-8\r\n\r\npandas ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57749', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57749/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57749/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57749/events', 'html_url': 'https://github.com/pandas-dev/pandas/issues/57749', 'id': 2171388786, 'node_id': 'I_kwDOAA0YD86BbMNy', 'number': 57749, 'title': 'BUG: `Timestamp.unit` should reflect changes in components after `Timestamp.replace`', 'user': {'login': 'wjsi', 'id': 8284922, 'node_id': 'MDQ6VXNlcjgyODQ5MjI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8284922?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/wjsi', 'html_url': 'https://github.com/wjsi', 'followers_url': 'https://api.github.com/users/wjsi/followers', 'following_url': 'https://api.github.com/users/wjsi/following{/other_user}', 'gists_url': 'https://api.github.com/users/wjsi/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/wjsi/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/wjsi/subscriptions', 'organizations_url': 'https://api.github.com/users/wjsi/orgs', 'repos_url': 'https://api.github.com/users/wjsi/repos', 'events_url': 'https://api.github.com/users/wjsi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/wjsi/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug', 'name': 'Bug', 'color': 'e10c02', 'default': False, 'description': None}, {'id': 3713792788, 'node_id': 'LA_kwDOAA0YD87dW_sU', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Non-Nano', 'name': 'Non-Nano', 'color': '006b75', 'default': False, 'description': 'datetime64/timedelta64 with non-nanosecond resolution'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2024-03-06T12:26:27Z', 'updated_at': '2024-03-06T17:43:08Z', 'closed_at': None, 'author_association': 'CONTRIBUTOR', 'active_lock_reason': None, 'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport datetime\r\nimport pandas as pd\r\n\r\nts = pd.Timestamp("2023-07-15 23:08:12.134567123")\r\nprint(ts)  # shows Timestamp(\'2023-07-16 23:08:12.134567123\')\r\nts2 = pd.Timestamp(datetime.datetime.utcfromtimestamp(int(ts.timestamp())))\r\nts2 = ts2.replace(microsecond=ts.microsecond, nanosecond=ts.nanosecond)\r\nprint(ts2)  # shows Timestamp(\'2023-07-16 23:08:12.134567123\')\r\nassert ts == ts2  # fails\n```\n\n\n### Issue Description\n\nWhile repr(ts) and repr(ts2) are equal, direct comparison fails.\n\n### Expected Behavior\n\nts and ts2 shall be equal.\n\n### Installed Versions\n\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : bdc79c146c2e32f2cab629be240f01658cfb6cc2\r\npython                : 3.9.16.final.0\r\npython-bits           : 64\r\nOS                    : Darwin\r\nOS-release            : 22.5.0\r\nVersion               : Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:22 PDT 2023; root:xnu-8796.121.3~7/RELEASE_X86_64\r\nmachine               : x86_64\r\nprocessor             : i386\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : zh_CN.UTF-8\r\nLOCALE                : zh_CN.UTF-8\r\n\r\npandas                : 2.2.1\r\nnumpy                 : 1.25.2\r\npytz                  : 2 ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57748', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57748/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57748/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57748/events', 'html_url': 'https://github.com/pandas-dev/pandas/issues/57748', 'id': 2171181760, 'node_id': 'I_kwDOAA0YD86BaZrA', 'number': 57748, 'title': 'ENH: No longer always show hour, minute and second components for pd.Interval ', 'user': {'login': 'ClaireDons', 'id': 82878115, 'node_id': 'MDQ6VXNlcjgyODc4MTE1', 'avatar_url': 'https://avatars.githubusercontent.com/u/82878115?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ClaireDons', 'html_url': 'https://github.com/ClaireDons', 'followers_url': 'https://api.github.com/users/ClaireDons/followers', 'following_url': 'https://api.github.com/users/ClaireDons/following{/other_user}', 'gists_url': 'https://api.github.com/users/ClaireDons/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ClaireDons/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ClaireDons/subscriptions', 'organizations_url': 'https://api.github.com/users/ClaireDons/orgs', 'repos_url': 'https://api.github.com/users/ClaireDons/repos', 'events_url': 'https://api.github.com/users/ClaireDons/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ClaireDons/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement', 'name': 'Enhancement', 'color': '4E9A06', 'default': False, 'description': None}, {'id': 1954720290, 'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage', 'name': 'Needs Triage', 'color': '0052cc', 'default': False, 'description': 'Issue that has not been reviewed by a pandas team member'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2024-03-06T10:39:28Z', 'updated_at': '2024-03-06T13:30:54Z', 'closed_at': None, 'author_association': 'NONE', 'active_lock_reason': None, 'body': '### Feature Type\n\n- [ ] Adding new functionality to pandas\n\n- [X] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\n`pd.Interval` behaviour change from #55035 means that hour, minute and second components is always shown regardless of if timezone is included as an argument. The default behaviour until now has been for time to be dropped if 00:00:00. In our use-case this broke some tests and does not provide useful information. \r\n\r\n```\r\n  -    anchor_year  i_interval                  interval   data  is_target\r\n    -0          2019          -1  [2019-07-04, 2019-12-31)   14.5      False\r\n    -1          2019           1  [2019-12-31, 2020-06-28)  119.5       True\r\n    -2          2020          -1  [2020-07-04, 2020-12-31)  305.5      False\r\n    -3          2020           1  [2020-12-31, 2021-06-29)  485.5       True\r\n    +   anchor_year  i_interval                                    interval   data  is_target\r\n    +0         2019          -1  [2019-07-04 00:00:00, 2019-12-31 00:00:00)   14.5      False\r\n    +1         2019           1  [2019-12-31 00:00:00, 2020-06-28 00:00:00)  119.5       True\r\n    +2         2020          -1  [2020-07-04 00:00:00, 2020-12-31 00:00:00)  305.5      False\r\n    +3         2020           1  [2020-12-31 00:00:00, 2021-06-29 00:00:00)  485.5       True\r\n```\n\n### Feature Description\n\nIt would be nice to revert to dropping hour, minute and second components when 00:00:00 and when no timezone is specified. \n\n### Alternative Solutions\n\nN/A\n\n### Additional Context\n\n_No respo ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57747', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57747/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57747/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57747/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57747', 'id': 2170931074, 'node_id': 'PR_kwDOAA0YD85ozwqY', 'number': 57747, 'title': 'CI: only keep conda cache for one day', 'user': {'login': 'jorisvandenbossche', 'id': 1020496, 'node_id': 'MDQ6VXNlcjEwMjA0OTY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jorisvandenbossche', 'html_url': 'https://github.com/jorisvandenbossche', 'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers', 'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}', 'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions', 'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs', 'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos', 'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI', 'name': 'CI', 'color': 'a2bca7', 'default': False, 'description': 'Continuous Integration'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2024-03-06T08:35:21Z', 'updated_at': '2024-03-06T17:04:26Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': True, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57747', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57747', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57747.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57747.patch', 'merged_at': None}, 'body': "Our conda envs are being cached, but that also means that for the dev builds (eg numpy nightly, pyarrow nightly), you don't actually get the latest version, depending on whether some other change happened in the CI setup that would invalidate the cache.\r\n\r\nMaybe ideally we do this _only_ for those builds that test for other dev packages? \r\n\r\nFrom https://github.com/mamba-org/setup-micromamba?tab=readme-ov-file#caching  \r\nRelated issue: https://github.com/mamba-org/setup-micromamba/issues/50", 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57747/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57747/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57746', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57746/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57746/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57746/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57746', 'id': 2170590457, 'node_id': 'PR_kwDOAA0YD85oym37', 'number': 57746, 'title': 'CLN: Enforce deprecation of groupby.idxmin/idxmax with skipna=False not raising', 'user': {'login': 'rhshadrach', 'id': 45562402, 'node_id': 'MDQ6VXNlcjQ1NTYyNDAy', 'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rhshadrach', 'html_url': 'https://github.com/rhshadrach', 'followers_url': 'https://api.github.com/users/rhshadrach/followers', 'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}', 'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions', 'organizations_url': 'https://api.github.com/users/rhshadrach/orgs', 'repos_url': 'https://api.github.com/users/rhshadrach/repos', 'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rhshadrach/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 233160, 'node_id': 'MDU6TGFiZWwyMzMxNjA=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby', 'name': 'Groupby', 'color': '729FCF', 'default': False, 'description': None}, {'id': 2822342, 'node_id': 'MDU6TGFiZWwyODIyMzQy', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data', 'name': 'Missing-data', 'color': 'd7e102', 'default': False, 'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'}, {'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean', 'name': 'Clean', 'color': '207de5', 'default': False, 'description': None}, {'id': 2365504383, 'node_id': 'MDU6TGFiZWwyMzY1NTA0Mzgz', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reduction%20Operations', 'name': 'Reduction Operations', 'color': '547c03', 'default': False, 'description': 'sum, mean, min, max, etc.'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102', 'html_url': 'https://github.com/pandas-dev/pandas/milestone/102', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels', 'id': 9021906, 'node_id': 'MI_kwDOAA0YD84AianS', 'number': 102, 'title': '3.0', 'description': '', 'creator': {'login': 'jbrockmendel', 'id': 8078968, 'node_id': 'MDQ6VXNlcjgwNzg5Njg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jbrockmendel', 'html_url': 'https://github.com/jbrockmendel', 'followers_url': 'https://api.github.com/users/jbrockmendel/followers', 'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}', 'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions', 'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs', 'repos_url': 'https://api.github.com/users/jbrockmendel/repos', 'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events', 'type': 'User', 'site_admin': False}, 'open_issues': 55, 'closed_issues': 352, 'state': 'open',  ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57745', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57745/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57745/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57745/events', 'html_url': 'https://github.com/pandas-dev/pandas/issues/57745', 'id': 2170582313, 'node_id': 'I_kwDOAA0YD86BYHUp', 'number': 57745, 'title': 'DEPR: groupby.idxmin/idxmax will all NA values', 'user': {'login': 'rhshadrach', 'id': 45562402, 'node_id': 'MDQ6VXNlcjQ1NTYyNDAy', 'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rhshadrach', 'html_url': 'https://github.com/rhshadrach', 'followers_url': 'https://api.github.com/users/rhshadrach/followers', 'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}', 'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions', 'organizations_url': 'https://api.github.com/users/rhshadrach/orgs', 'repos_url': 'https://api.github.com/users/rhshadrach/repos', 'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rhshadrach/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 233160, 'node_id': 'MDU6TGFiZWwyMzMxNjA=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby', 'name': 'Groupby', 'color': '729FCF', 'default': False, 'description': None}, {'id': 2822342, 'node_id': 'MDU6TGFiZWwyODIyMzQy', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data', 'name': 'Missing-data', 'color': 'd7e102', 'default': False, 'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'}, {'id': 87485152, 'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate', 'name': 'Deprecate', 'color': '5319e7', 'default': False, 'description': 'Functionality to remove in pandas'}, {'id': 2365504383, 'node_id': 'MDU6TGFiZWwyMzY1NTA0Mzgz', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reduction%20Operations', 'name': 'Reduction Operations', 'color': '547c03', 'default': False, 'description': 'sum, mean, min, max, etc.'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/115', 'html_url': 'https://github.com/pandas-dev/pandas/milestone/115', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/115/labels', 'id': 10357884, 'node_id': 'MI_kwDOAA0YD84Angx8', 'number': 115, 'title': '4.0', 'description': None, 'creator': {'login': 'lithomas1', 'id': 47963215, 'node_id': 'MDQ6VXNlcjQ3OTYzMjE1', 'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lithomas1', 'html_url': 'https://github.com/lithomas1', 'followers_url': 'https://api.github.com/users/lithomas1/followers', 'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}', 'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions', 'organizations_url': 'https://api.github.com/users/lithomas1/orgs', 'repos_url': 'https://api.github.com/users/lithomas1/repos', 'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lithomas1/received_events', 'type': 'User', 'site_admin': False}, 'open_issues': 2, 'closed_issues': 0, 'state': 'open', 'created_at': '2023-12-29T18 ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57744', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57744/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57744/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57744/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57744', 'id': 2170550707, 'node_id': 'PR_kwDOAA0YD85oyd_K', 'number': 57744, 'title': 'CLN: Enforce deprecation of groupby.quantile supporting bool dtype', 'user': {'login': 'rhshadrach', 'id': 45562402, 'node_id': 'MDQ6VXNlcjQ1NTYyNDAy', 'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rhshadrach', 'html_url': 'https://github.com/rhshadrach', 'followers_url': 'https://api.github.com/users/rhshadrach/followers', 'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}', 'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions', 'organizations_url': 'https://api.github.com/users/rhshadrach/orgs', 'repos_url': 'https://api.github.com/users/rhshadrach/repos', 'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rhshadrach/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 233160, 'node_id': 'MDU6TGFiZWwyMzMxNjA=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby', 'name': 'Groupby', 'color': '729FCF', 'default': False, 'description': None}, {'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean', 'name': 'Clean', 'color': '207de5', 'default': False, 'description': None}, {'id': 1631984902, 'node_id': 'MDU6TGFiZWwxNjMxOTg0OTAy', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/quantile', 'name': 'quantile', 'color': '006b75', 'default': False, 'description': 'quantile method'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102', 'html_url': 'https://github.com/pandas-dev/pandas/milestone/102', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels', 'id': 9021906, 'node_id': 'MI_kwDOAA0YD84AianS', 'number': 102, 'title': '3.0', 'description': '', 'creator': {'login': 'jbrockmendel', 'id': 8078968, 'node_id': 'MDQ6VXNlcjgwNzg5Njg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jbrockmendel', 'html_url': 'https://github.com/jbrockmendel', 'followers_url': 'https://api.github.com/users/jbrockmendel/followers', 'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}', 'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions', 'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs', 'repos_url': 'https://api.github.com/users/jbrockmendel/repos', 'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events', 'type': 'User', 'site_admin': False}, 'open_issues': 55, 'closed_issues': 352, 'state': 'open', 'created_at': '2023-02-08T18:16:49Z', 'updated_at': '2024-03-06T07:32:45Z', 'due_on': '2024-04-01T07:00:00Z', 'closed_at': None}, 'comments': 0, 'created_at': '2024-03-06T03:28:08Z', 'updated_at': '2024-03-06T15:05:11Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57743', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57743/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57743/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57743/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57743', 'id': 2170524253, 'node_id': 'PR_kwDOAA0YD85oyYYJ', 'number': 57743, 'title': 'CLN: Enforce deprecation get_group with tuples of length 1', 'user': {'login': 'rhshadrach', 'id': 45562402, 'node_id': 'MDQ6VXNlcjQ1NTYyNDAy', 'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rhshadrach', 'html_url': 'https://github.com/rhshadrach', 'followers_url': 'https://api.github.com/users/rhshadrach/followers', 'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}', 'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions', 'organizations_url': 'https://api.github.com/users/rhshadrach/orgs', 'repos_url': 'https://api.github.com/users/rhshadrach/repos', 'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rhshadrach/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 233160, 'node_id': 'MDU6TGFiZWwyMzMxNjA=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby', 'name': 'Groupby', 'color': '729FCF', 'default': False, 'description': None}, {'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean', 'name': 'Clean', 'color': '207de5', 'default': False, 'description': None}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102', 'html_url': 'https://github.com/pandas-dev/pandas/milestone/102', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels', 'id': 9021906, 'node_id': 'MI_kwDOAA0YD84AianS', 'number': 102, 'title': '3.0', 'description': '', 'creator': {'login': 'jbrockmendel', 'id': 8078968, 'node_id': 'MDQ6VXNlcjgwNzg5Njg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jbrockmendel', 'html_url': 'https://github.com/jbrockmendel', 'followers_url': 'https://api.github.com/users/jbrockmendel/followers', 'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}', 'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions', 'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs', 'repos_url': 'https://api.github.com/users/jbrockmendel/repos', 'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events', 'type': 'User', 'site_admin': False}, 'open_issues': 55, 'closed_issues': 352, 'state': 'open', 'created_at': '2023-02-08T18:16:49Z', 'updated_at': '2024-03-06T07:32:45Z', 'due_on': '2024-04-01T07:00:00Z', 'closed_at': None}, 'comments': 0, 'created_at': '2024-03-06T02:55:35Z', 'updated_at': '2024-03-06T03:17:35Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57743', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57743', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57743.diff', 'patch ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57742', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57742/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57742/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57742/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57742', 'id': 2170509369, 'node_id': 'PR_kwDOAA0YD85oyVOQ', 'number': 57742, 'title': 'CLN: Enforce deprecation of method and limit in pct_change methods', 'user': {'login': 'rhshadrach', 'id': 45562402, 'node_id': 'MDQ6VXNlcjQ1NTYyNDAy', 'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rhshadrach', 'html_url': 'https://github.com/rhshadrach', 'followers_url': 'https://api.github.com/users/rhshadrach/followers', 'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}', 'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions', 'organizations_url': 'https://api.github.com/users/rhshadrach/orgs', 'repos_url': 'https://api.github.com/users/rhshadrach/repos', 'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rhshadrach/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 2822342, 'node_id': 'MDU6TGFiZWwyODIyMzQy', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data', 'name': 'Missing-data', 'color': 'd7e102', 'default': False, 'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'}, {'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean', 'name': 'Clean', 'color': '207de5', 'default': False, 'description': None}, {'id': 5432589519, 'node_id': 'LA_kwDOAA0YD88AAAABQ868zw', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Transformations', 'name': 'Transformations', 'color': '5319e7', 'default': False, 'description': 'e.g. cumsum, diff, rank'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102', 'html_url': 'https://github.com/pandas-dev/pandas/milestone/102', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels', 'id': 9021906, 'node_id': 'MI_kwDOAA0YD84AianS', 'number': 102, 'title': '3.0', 'description': '', 'creator': {'login': 'jbrockmendel', 'id': 8078968, 'node_id': 'MDQ6VXNlcjgwNzg5Njg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jbrockmendel', 'html_url': 'https://github.com/jbrockmendel', 'followers_url': 'https://api.github.com/users/jbrockmendel/followers', 'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}', 'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions', 'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs', 'repos_url': 'https://api.github.com/users/jbrockmendel/repos', 'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events', 'type': 'User', 'site_admin': False}, 'open_issues': 55, 'closed_issues': 352, 'state': 'open', 'created_at': '2023-02-08T18:16:49Z', 'updated_at': '2024-03-06T07:32:45Z', 'due_on': '2024-04-01T07:00:00Z', 'closed_at': None}, 'comments': 0, 'created_at': '2024-03-06T02:37:11Z', 'updated_at': '2024-03-06T03:06:01Z', 'clos ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57741', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57741/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57741/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57741/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57741', 'id': 2170478510, 'node_id': 'PR_kwDOAA0YD85oyOs0', 'number': 57741, 'title': 'CLN: Enforce deprecation of groupby with as_index=False excluding out-of-axis groupings', 'user': {'login': 'rhshadrach', 'id': 45562402, 'node_id': 'MDQ6VXNlcjQ1NTYyNDAy', 'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rhshadrach', 'html_url': 'https://github.com/rhshadrach', 'followers_url': 'https://api.github.com/users/rhshadrach/followers', 'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}', 'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions', 'organizations_url': 'https://api.github.com/users/rhshadrach/orgs', 'repos_url': 'https://api.github.com/users/rhshadrach/repos', 'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rhshadrach/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 233160, 'node_id': 'MDU6TGFiZWwyMzMxNjA=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby', 'name': 'Groupby', 'color': '729FCF', 'default': False, 'description': None}, {'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean', 'name': 'Clean', 'color': '207de5', 'default': False, 'description': None}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102', 'html_url': 'https://github.com/pandas-dev/pandas/milestone/102', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels', 'id': 9021906, 'node_id': 'MI_kwDOAA0YD84AianS', 'number': 102, 'title': '3.0', 'description': '', 'creator': {'login': 'jbrockmendel', 'id': 8078968, 'node_id': 'MDQ6VXNlcjgwNzg5Njg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jbrockmendel', 'html_url': 'https://github.com/jbrockmendel', 'followers_url': 'https://api.github.com/users/jbrockmendel/followers', 'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}', 'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions', 'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs', 'repos_url': 'https://api.github.com/users/jbrockmendel/repos', 'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events', 'type': 'User', 'site_admin': False}, 'open_issues': 55, 'closed_issues': 352, 'state': 'open', 'created_at': '2023-02-08T18:16:49Z', 'updated_at': '2024-03-06T07:32:45Z', 'due_on': '2024-04-01T07:00:00Z', 'closed_at': None}, 'comments': 0, 'created_at': '2024-03-06T02:03:31Z', 'updated_at': '2024-03-06T02:03:31Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57741', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57741', 'diff_url': 'https://github.com/pandas-dev/pa ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57739', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57739/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57739/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57739/events', 'html_url': 'https://github.com/pandas-dev/pandas/issues/57739', 'id': 2170200544, 'node_id': 'I_kwDOAA0YD86BWqHg', 'number': 57739, 'title': 'COMPAT: Utilize `copy` keyword in `__array__`', 'user': {'login': 'mroeschke', 'id': 10647082, 'node_id': 'MDQ6VXNlcjEwNjQ3MDgy', 'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mroeschke', 'html_url': 'https://github.com/mroeschke', 'followers_url': 'https://api.github.com/users/mroeschke/followers', 'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}', 'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions', 'organizations_url': 'https://api.github.com/users/mroeschke/orgs', 'repos_url': 'https://api.github.com/users/mroeschke/repos', 'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mroeschke/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 76865106, 'node_id': 'MDU6TGFiZWw3Njg2NTEwNg==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Compat', 'name': 'Compat', 'color': '0052cc', 'default': False, 'description': 'pandas objects compatability with Numpy or Python functions'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102', 'html_url': 'https://github.com/pandas-dev/pandas/milestone/102', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels', 'id': 9021906, 'node_id': 'MI_kwDOAA0YD84AianS', 'number': 102, 'title': '3.0', 'description': '', 'creator': {'login': 'jbrockmendel', 'id': 8078968, 'node_id': 'MDQ6VXNlcjgwNzg5Njg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jbrockmendel', 'html_url': 'https://github.com/jbrockmendel', 'followers_url': 'https://api.github.com/users/jbrockmendel/followers', 'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}', 'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions', 'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs', 'repos_url': 'https://api.github.com/users/jbrockmendel/repos', 'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events', 'type': 'User', 'site_admin': False}, 'open_issues': 55, 'closed_issues': 352, 'state': 'open', 'created_at': '2023-02-08T18:16:49Z', 'updated_at': '2024-03-06T07:32:45Z', 'due_on': '2024-04-01T07:00:00Z', 'closed_at': None}, 'comments': 1, 'created_at': '2024-03-05T21:49:15Z', 'updated_at': '2024-03-06T07:35:14Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'body': 'https://github.com/pandas-dev/pandas/pull/57172 add a copy keyword that will be passed in with `__array__` in Numpy 2.0. Currently it is unused but it would be useful to respect that option when passed', 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57739/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket':  ...
# ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57713', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57713/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57713/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57713/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57713', 'id': 2165418794, 'node_id': 'PR_kwDOAA0YD85og6qV', 'number': 57713, 'title': 'BUG: Line plots aligned from start #57594', 'user': {'login': 'NoelMT', 'id': 58369280, 'node_id': 'MDQ6VXNlcjU4MzY5Mjgw', 'avatar_url': 'https://avatars.githubusercontent.com/u/58369280?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/NoelMT', 'html_url': 'https://github.com/NoelMT', 'followers_url': 'https://api.github.com/users/NoelMT/followers', 'following_url': 'https://api.github.com/users/NoelMT/following{/other_user}', 'gists_url': 'https://api.github.com/users/NoelMT/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/NoelMT/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/NoelMT/subscriptions', 'organizations_url': 'https://api.github.com/users/NoelMT/orgs', 'repos_url': 'https://api.github.com/users/NoelMT/repos', 'events_url': 'https://api.github.com/users/NoelMT/events{/privacy}', 'received_events_url': 'https://api.github.com/users/NoelMT/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 2413328, 'node_id': 'MDU6TGFiZWwyNDEzMzI4', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Visualization', 'name': 'Visualization', 'color': '8AE234', 'default': False, 'description': 'plotting'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2024-03-03T15:34:23Z', 'updated_at': '2024-03-05T19:04:56Z', 'closed_at': None, 'author_association': 'NONE', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57713', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57713', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57713.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57713.patch', 'merged_at': None}, 'body': '#57594 BUG: df.plot makes a shift to the right if frequency multiplies to n > 1\r\n\r\nThe cause of this bug is that by default all elements are generated to align to the end of\r\na period instead of at the start and the period technically does not end at the start of\r\nthe last period but rather just before the period subsequent to the last period. To fix this\r\nproblem we therefore passed a parameter stating that the elements should be aligned to\r\nthe start of the period instead of the end. Parameter "how=S" was added in pandas/plotting/_matplotlib/timeseries.py::maybe_convert_index(), \r\non the function call data.index.asfreq(freq=freq_str, how = "S").  \r\n\r\nAdditional tests were added to test whether input data match data in plot and one test was merged into one the added test to reduce code duplication. ', 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57713/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57713/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57712', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57712/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57712/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57712/events', 'html_url': 'https://github.com/pandas-dev/pandas/issues/57712', 'id': 2165342657, 'node_id': 'I_kwDOAA0YD86BEIHB', 'number': 57712, 'title': 'Potential regression induced by PR #57588', 'user': {'login': 'DeaMariaLeon', 'id': 11835246, 'node_id': 'MDQ6VXNlcjExODM1MjQ2', 'avatar_url': 'https://avatars.githubusercontent.com/u/11835246?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/DeaMariaLeon', 'html_url': 'https://github.com/DeaMariaLeon', 'followers_url': 'https://api.github.com/users/DeaMariaLeon/followers', 'following_url': 'https://api.github.com/users/DeaMariaLeon/following{/other_user}', 'gists_url': 'https://api.github.com/users/DeaMariaLeon/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/DeaMariaLeon/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/DeaMariaLeon/subscriptions', 'organizations_url': 'https://api.github.com/users/DeaMariaLeon/orgs', 'repos_url': 'https://api.github.com/users/DeaMariaLeon/repos', 'events_url': 'https://api.github.com/users/DeaMariaLeon/events{/privacy}', 'received_events_url': 'https://api.github.com/users/DeaMariaLeon/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 732775912, 'node_id': 'MDU6TGFiZWw3MzI3NzU5MTI=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Benchmark', 'name': 'Benchmark', 'color': 'ae68cc', 'default': False, 'description': 'Performance (ASV) benchmarks'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2024-03-03T12:50:21Z', 'updated_at': '2024-03-03T19:29:40Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'body': "\r\nPR #57588\r\n\r\nIf this is expected please ignore this issue. \r\n\r\nThe largest regressions seem to be the benchmarks bellow. \r\nedit: the names of all the benchmarks with links to their plot are in the attached file.\r\n\r\n`series_methods.Dropna.time_dropna` (Python) with dtype='datetime'\r\n`groupby.GroupByMethods.time_dtype_as_field` (Python) with application='direct', dtype='int16', method='head', ncols=1, param5='cython'\r\n`groupby.Nth.time_series_nth_all` (Python) with dtype='datetime'\r\n\r\n@mroeschke\r\n\r\n[cleaned_regression_file.json](https://github.com/pandas-dev/pandas/files/14473488/cleaned_regression_file.json)\r\n\r\n\r\n![Screenshot 2024-03-03 at 13 26 15](https://github.com/pandas-dev/pandas/assets/11835246/8f8432af-42b5-42e4-827e-a8805bd28e59)\r\n", 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57712/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57712/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57710', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57710/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57710/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57710/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57710', 'id': 2165021095, 'node_id': 'PR_kwDOAA0YD85ofn8l', 'number': 57710, 'title': 'REF: Remove dynamic docstrings from option methods', 'user': {'login': 'mroeschke', 'id': 10647082, 'node_id': 'MDQ6VXNlcjEwNjQ3MDgy', 'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mroeschke', 'html_url': 'https://github.com/mroeschke', 'followers_url': 'https://api.github.com/users/mroeschke/followers', 'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}', 'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions', 'organizations_url': 'https://api.github.com/users/mroeschke/orgs', 'repos_url': 'https://api.github.com/users/mroeschke/repos', 'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mroeschke/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 127681, 'node_id': 'MDU6TGFiZWwxMjc2ODE=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor', 'name': 'Refactor', 'color': 'FCE94F', 'default': False, 'description': 'Internal refactoring of code'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-03-02T23:09:36Z', 'updated_at': '2024-03-06T00:10:11Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57710', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57710', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57710.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57710.patch', 'merged_at': None}, 'body': "xref https://github.com/pandas-dev/pandas/issues/57578#issuecomment-1960937283\r\n\r\nThese methods have complex docstrings in an attempt to display all option within the docstring. This makes these docstrings hard to automatically validate and [renders the internal implementation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.describe_option.html#pandas.describe_option) in Sphinx. I think it's reasonable to link to the docs where all the options are listed instead.\r\n\r\nAdditionally did some cleanups removing `silent` from some of these methods by instead catching warnings where needed\r\n\r\n", 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57710/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57710/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57709', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57709/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57709/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57709/events', 'html_url': 'https://github.com/pandas-dev/pandas/issues/57709', 'id': 2165019795, 'node_id': 'I_kwDOAA0YD86BC5ST', 'number': 57709, 'title': 'BUG: Boxplot does not apply colors set by Matplotlib rcParams for certain plot elements', 'user': {'login': 'thetestspecimen', 'id': 40262729, 'node_id': 'MDQ6VXNlcjQwMjYyNzI5', 'avatar_url': 'https://avatars.githubusercontent.com/u/40262729?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/thetestspecimen', 'html_url': 'https://github.com/thetestspecimen', 'followers_url': 'https://api.github.com/users/thetestspecimen/followers', 'following_url': 'https://api.github.com/users/thetestspecimen/following{/other_user}', 'gists_url': 'https://api.github.com/users/thetestspecimen/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/thetestspecimen/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/thetestspecimen/subscriptions', 'organizations_url': 'https://api.github.com/users/thetestspecimen/orgs', 'repos_url': 'https://api.github.com/users/thetestspecimen/repos', 'events_url': 'https://api.github.com/users/thetestspecimen/events{/privacy}', 'received_events_url': 'https://api.github.com/users/thetestspecimen/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug', 'name': 'Bug', 'color': 'e10c02', 'default': False, 'description': None}, {'id': 1954720290, 'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage', 'name': 'Needs Triage', 'color': '0052cc', 'default': False, 'description': 'Issue that has not been reviewed by a pandas team member'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-03-02T23:04:34Z', 'updated_at': '2024-03-02T23:18:30Z', 'closed_at': None, 'author_association': 'NONE', 'active_lock_reason': None, 'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport numpy as np\r\nimport pandas as pd\r\nimport matplotlib.pyplot as plt\r\nimport matplotlib as mpl\r\ndf = pd.DataFrame(np.random.default_rng(12).random((10, 2)))\r\nwith mpl.rc_context({\'boxplot.boxprops.color\': \'red\',\r\n                     \'boxplot.whiskerprops.color\': \'green\',\r\n                     \'boxplot.capprops.color\': \'orange\',\r\n                     \'boxplot.medianprops.color\': \'cyan\',\r\n                     \'patch.facecolor\': \'grey\'}):\r\n    df.plot.box(patch_artist=True) # OR df.plot(kind=\'box\', patch_artist=True)\r\n    plt.show()\n```\n\n\n### Issue Description\n\nIf the \'Reproducible Example\' code is run it will result in the following:\r\n\r\n![pandas-example](https://github.com/pandas-dev/pandas/assets/40262729/f37f4507-2715-4962-b4ec-d9446014093d)\r\n\r\nIf run directly through Matplotlib like so:\r\n\r\n```python\r\nimport numpy as np\r\nimport pandas as pd\r\nimport matplotlib.pyplot as plt\r\nimport matplotlib as mpl\r\ndf = pd.DataFrame(np.random.default_rng(12).random((10, 2)))\r\nwith mpl.rc_context({\'boxplot.boxprops.color\': \'red\',\r\n                 ...

# %%
pd.DataFrame(df)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/57751  2172082442
# 1   https://github.com/pandas-dev/pandas/issues/57750  2172010198
# 2   https://github.com/pandas-dev/pandas/issues/57749  2171388786
# 3   https://github.com/pandas-dev/pandas/issues/57748  2171181760
# 4     https://github.com/pandas-dev/pandas/pull/57747  2170931074
# 5     https://github.com/pandas-dev/pandas/pull/57746  2170590457
# 6   https://github.com/pandas-dev/pandas/issues/57745  2170582313
# 7     https://github.com/pandas-dev/pandas/pull/57744  2170550707
# 8     https://github.com/pandas-dev/pandas/pull/57743  2170524253
# 9     https://github.com/pandas-dev/pandas/pull/57742  2170509369
# 10    https://github.com/pandas-dev/pandas/pull/57741  2170478510
# 11  https://github.com/pandas-dev/pandas/issues/57739  2170200544
# 12  https://github.com/pandas-dev/pandas/issues/57738  2169952694
# 13    https://github.com/pandas-dev/pandas/pull/57737  2169859389
# 14  https://github.com/pandas-dev/pandas/issues/57736  2169745272
# 15  https://github.com/pandas-dev/pandas/issues/57735  2169491951
# 16  https://github.com/pandas-dev/pandas/issues/57734  2169350158
# 17    https://github.com/pandas-dev/pandas/pull/57733  2168736610
# 18  https://github.com/pandas-dev/pandas/issues/57731  2168136869
# 19    https://github.com/pandas-dev/pandas/pull/57730  2168134519
# 20    https://github.com/pandas-dev/pandas/pull/57725  2167293513
# 21  https://github.com/pandas-dev/pandas/issues/57724  2167216233
# 22  https://github.com/pandas-dev/pandas/issues/57723  2167029070
# 23  https://github.com/pandas-dev/pandas/issues/57722  2166895740
# 24  https://github.com/pandas-dev/pandas/issues/57717  2166644671
# 25  https://github.com/pandas-dev/pandas/issues/57716  2165790488
# 26    https://github.com/pandas-dev/pandas/pull/57713  2165418794
# 27  https://github.com/pandas-dev/pandas/issues/57712  2165342657
# 28    https://github.com/pandas-dev/pandas/pull/57710  2165021095
# 29  https://github.com/pandas-dev/pandas/issues/57709  2165019795
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD85o3uMP   57751
# 1    I_kwDOAA0YD86Bdj7W   57750
# 2    I_kwDOAA0YD86BbMNy   57749
# 3    I_kwDOAA0YD86BaZrA   57748
# 4   PR_kwDOAA0YD85ozwqY   57747
# 5   PR_kwDOAA0YD85oym37   57746
# 6    I_kwDOAA0YD86BYHUp   57745
# 7   PR_kwDOAA0YD85oyd_K   57744
# 8   PR_kwDOAA0YD85oyYYJ   57743
# 9   PR_kwDOAA0YD85oyVOQ   57742
# 10  PR_kwDOAA0YD85oyOs0   57741
# 11   I_kwDOAA0YD86BWqHg   57739
# 12   I_kwDOAA0YD86BVtm2   57738
# 13  PR_kwDOAA0YD85owGgM   57737
# 14   I_kwDOAA0YD86BU694   57736
# 15   I_kwDOAA0YD86BT9Hv   57735
# 16   I_kwDOAA0YD86BTagO   57734
# 17  PR_kwDOAA0YD85osPCE   57733
# 18   I_kwDOAA0YD86BOySl   57731
# 19  PR_kwDOAA0YD85oqMeK   57730
# 20  PR_kwDOAA0YD85onTyj   57725
# 21   I_kwDOAA0YD86BLRhp   57724
# 22   I_kwDOAA0YD86BKj1O   57723
# 23   I_kwDOAA0YD86BKDR8   57722
# 24   I_kwDOAA0YD86BJF-_   57717
# 25   I_kwDOAA0YD86BF1cY   57716
# 26  PR_kwDOAA0YD85og6qV   57713
# 27   I_kwDOAA0YD86BEIHB   57712
# 28  PR_kwDOAA0YD85ofn8l   57710
# 29   I_kwDOAA0YD86BC5ST   57709
#
#                                                 title  ... closed_at  \
# 0        DOC: fixing GL08 errors for pandas.Series.dt  ...      None
# 1   BUG: .loc operation cannot locate existing ind...  ...      None
# 2   BUG: `Timestamp.unit` should reflect changes i...  ...      None
# 3   ENH: No longer always show hour, minute and se...  ...      None
# 4               CI: only keep conda cache for one day  ...      None
# 5   CLN: Enforce deprecation of groupby.idxmin/idx...  ...      None
# 6      DEPR: groupby.idxmin/idxmax will all NA values  ...      None
# 7   CLN: Enforce deprecation of groupby.quantile s...  ...      None
# 8   CLN: Enforce deprecation get_group with tuples...  ...      None
# 9   CLN: Enforce deprecation of method and limit i...  ...      None
# 10  CLN: Enforce deprecation of groupby with as_in...  ...      None
# 11      COMPAT: Utilize `copy` keyword in `__array__`  ...      None
# 12  BUG:  Convertion fails for columns with dateti...  ...      None
# 13  CI/TST: Use worksteal over loadfile for pytest...  ...      None
# 14                      ENH: Assign for pandas Series  ...      None
# 15    BUG: ValueError with loc[] = (Regression 2.1.0)  ...      None
# 16  QST: How to solve pandas (2.2.0) "FutureWarnin...  ...      None
# 17                     PERF: improve StringArray.isna  ...      None
# 18                   ENH: interleave_columns function  ...      None
# 19                Replace khash + tempita with khashl  ...      None
# 20              [pre-commit.ci] pre-commit autoupdate  ...      None
# 21       BUG: to_sql does not get the correct dialect  ...      None
# 22  BUG: fillna() doesn't work with `value=None` w...  ...      None
# 23                     DOC: SQL-style join conditions  ...      None
# 24  BUILD: error: metadata-generation-failed; ninj...  ...      None
# 25          Pandas Extension: Drop Duplicated Columns  ...      None
# 26          BUG: Line plots aligned from start #57594  ...      None
# 27          Potential regression induced by PR #57588  ...      None
# 28  REF: Remove dynamic docstrings from option met...  ...      None
# 29  BUG: Boxplot does not apply colors set by Matp...  ...      None
#
#    author_association active_lock_reason  draft  \
# 0                NONE               None  False
# 1                NONE               None    NaN
# 2         CONTRIBUTOR               None    NaN
# 3                NONE               None    NaN
# 4              MEMBER               None   True
# 5              MEMBER               None  False
# 6              MEMBER               None    NaN
# 7              MEMBER               None  False
# 8              MEMBER               None  False
# 9              MEMBER               None  False
# 10             MEMBER               None  False
# 11             MEMBER               None    NaN
# 12               NONE               None    NaN
# 13             MEMBER               None  False
# 14               NONE               None    NaN
# 15        CONTRIBUTOR               None    NaN
# 16               NONE               None    NaN
# 17             MEMBER               None  False
# 18        CONTRIBUTOR               None    NaN
# 19             MEMBER               None   True
# 20        CONTRIBUTOR               None  False
# 21               NONE               None    NaN
# 22        CONTRIBUTOR               None    NaN
# 23               NONE               None    NaN
# 24               NONE               None    NaN
# 25               NONE               None    NaN
# 26               NONE               None  False
# 27             MEMBER               None    NaN
# 28             MEMBER               None  False
# 29               NONE               None    NaN
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6                                                 NaN
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18                                                NaN
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29                                                NaN
#
#                                                  body  \
# 0   Resolved GL08 error for `scripts/validate_docs...
# 1   ### Pandas version checks\r\n\r\n- [X] I have ...
# 2   ### Pandas version checks\n\n- [X] I have chec...
# 3   ### Feature Type\n\n- [ ] Adding new functiona...
# 4   Our conda envs are being cached, but that also...
# 5   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 6   #54234 deprecated the case of `skipna=False` a...
# 7   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 8   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 9   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 10  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 11  https://github.com/pandas-dev/pandas/pull/5717...
# 12  ### Pandas version checks\n\n- [X] I have chec...
# 13  In theory, this should help alleviate a worker...
# 14  ### Feature Type\r\n\r\n- [X] Adding new funct...
# 15  ### Pandas version checks\n\n- [X] I have chec...
# 16  ### Research\n\n- [X] I have searched the [[pa...
# 17  See https://github.com/pandas-dev/pandas/issue...
# 18  ### Feature Type\n\n- [x] Adding new functiona...
# 19  supersedes #56432\r\n\r\nthis is just a resear...
# 20  <!--pre-commit.ci start-->\nupdates:\n- [githu...
# 21  ### Pandas version checks\n\n- [X] I have chec...
# 22  ### Pandas version checks\n\n- [X] I have chec...
# 23  ### Pandas version checks\n\n- [X] I have chec...
# 24  ### Installation check\n\n- [X] I have read th...
# 25  ### Feature Type\n\n- [X] Adding new functiona...
# 26  #57594 BUG: df.plot makes a shift to the right...
# 27  \r\nPR #57588\r\n\r\nIf this is expected pleas...
# 28  xref https://github.com/pandas-dev/pandas/issu...
# 29  ### Pandas version checks\n\n- [X] I have chec...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                      None         None
# 1                      None         None
# 2                      None         None
# 3                      None         None
# 4                      None         None
# 5                      None         None
# 6                      None         None
# 7                      None         None
# 8                      None         None
# 9                      None         None
# 10                     None         None
# 11                     None         None
# 12                     None         None
# 13                     None         None
# 14                     None         None
# 15                     None         None
# 16                     None         None
# 17                     None         None
# 18                     None         None
# 19                     None         None
# 20                     None         None
# 21                     None         None
# 22                     None         None
# 23                     None         None
# 24                     None         None
# 25                     None         None
# 26                     None         None
# 27                     None         None
# 28                     None         None
# 29                     None         None
#
# [30 rows x 30 columns]

# %%
df = pd.DataFrame(df, columns = ['user','timeline_url'])
df
# Out:
#                                                  user  \
# 0   {'login': 's1099', 'id': 46890315, 'node_id': ...
# 1   {'login': 'carlonlv', 'id': 36804238, 'node_id...
# 2   {'login': 'wjsi', 'id': 8284922, 'node_id': 'M...
# 3   {'login': 'ClaireDons', 'id': 82878115, 'node_...
# 4   {'login': 'jorisvandenbossche', 'id': 1020496,...
# 5   {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 6   {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 7   {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 8   {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 9   {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 10  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 11  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 12  {'login': 'alvarofagner', 'id': 2574079, 'node...
# 13  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 14  {'login': 'cbrummitt', 'id': 1268375, 'node_id...
# 15  {'login': 'rxxg', 'id': 8394766, 'node_id': 'M...
# 16  {'login': 'buhtz', 'id': 11861496, 'node_id': ...
# 17  {'login': 'jorisvandenbossche', 'id': 1020496,...
# 18  {'login': 'raybellwaves', 'id': 17162724, 'nod...
# 19  {'login': 'WillAyd', 'id': 609873, 'node_id': ...
# 20  {'login': 'pre-commit-ci[bot]', 'id': 66853113...
# 21  {'login': 'sls-mdr', 'id': 50274097, 'node_id'...
# 22  {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# 23  {'login': 'jxu', 'id': 7989982, 'node_id': 'MD...
# 24  {'login': 'Rand-0', 'id': 60578707, 'node_id':...
# 25  {'login': 'kanhapatil', 'id': 101468170, 'node...
# 26  {'login': 'NoelMT', 'id': 58369280, 'node_id':...
# 27  {'login': 'DeaMariaLeon', 'id': 11835246, 'nod...
# 28  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 29  {'login': 'thetestspecimen', 'id': 40262729, '...
#
#                                          timeline_url
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...

# %%
df.to_csv('json_info.csv')

# %%
## solving some dataset

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
