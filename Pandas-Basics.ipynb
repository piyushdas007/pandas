# %% [markdown]
# # **Pandas**

# %% [markdown]
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the python programming language.

# %% [markdown]
# **Pandas Series**

# %% [markdown]
# A pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# *Series from list*

# %%
# string
country = ['India','USA','Nepal','Bhutan']

pd.Series(country)
# Out:
# 0     India
# 1       USA
# 2     Nepal
# 3    Bhutan
# dtype: object

# %%
# integer
runs = [13,45,56,23,15]

pd.Series(runs)
# Out:
# 0    13
# 1    45
# 2    56
# 3    23
# 4    15
# dtype: int64

# %%
# custom index
marks = [67,57,89,37]
subjects = ['maths','english','science','hindi']


pd.Series(marks,index=subjects)
# Out:
# maths      67
# english    57
# science    89
# hindi      37
# dtype: int64

# %%
# setting a name
pd.Series(marks,index=subjects,name='piyush ke marks')
# Out:
# maths      67
# english    57
# science    89
# hindi      37
# Name: piyush ke marks, dtype: int64

# %% [markdown]
# *Series from dict*

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':37
}

marks_series = pd.Series(marks)
marks_series
# Out:
# maths      67
# english    57
# science    89
# hindi      37
# dtype: int64

# %% [markdown]
# *Series Attributes*

# %%
# size
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# is_unique
marks_series.is_unique

# pd.Series([1,2,3,4,5,1]).is_unique
# Out:
# True

# %%
# index
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
# values
marks_series.values
# Out:
# array([67, 57, 89, 37])

# %% [markdown]
# *Series using read_csv*

# %%
# with one col
pd.read_csv('/content/subs.csv')
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
# Above is DataFrame
# to convert into Series with 'squeeze'
subs = pd.read_csv('/content/subs.csv',squeeze=True)
subs
# Out:
# <ipython-input-18-a317757c58f7>:3: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   subs = pd.read_csv('/content/subs.csv',squeeze=True)
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# with 2 cols
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no',squeeze=True)
vk
# Out:
# <ipython-input-22-1c2c7d997d4a>:2: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no',squeeze=True)
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col='movie',squeeze=True)
movies
# Out:
# <ipython-input-25-27c5766633d2>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   movies = pd.read_csv('/content/bollywood.csv',index_col='movie',squeeze=True)
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# *Series method*

# %%
# head and tail
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
vk.tail()
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# sample
movies.sample(5)
# ramdomly selected movies
# Out:
# movie
# Teen Patti (film)          Amitabh Bachchan
# Khwaabb                       Simer Motiani
# Sukhmani: Hope for Life         Gurdas Maan
# Do Dooni Chaar                 Rishi Kapoor
# Aryan: Unbreakable              Sohail Khan
# Name: lead, dtype: object

# %%
# value_counts -> movies
movies.value_counts()
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: lead, Length: 566, dtype: int64

# %%
# sort_values -> inplace
vk.sort_values()
# Out:
# match_no
# 87       0
# 211      0
# 207      0
# 206      0
# 91       0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
vk.sort_values(inplace=True)
# changes table permanetly

# %%
# sort_index -> inplace -> movies
movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies.sort_index(inplace=True)
# changes the table permanently
# for decending order (ascending = False)

# %% [markdown]
# *Series Maths Method*

# %%
# count
vk.count()
# Out:
# 215

# %%
# sum --> product
subs.sum()
# also product
# Out:
# 49510

# %%
# mean -> median -> mode -> std -> var
subs.mean()
print(vk.median())
print(movies.mode())
print(subs.std())
print(vk.var())
# Out:
# 24.0
# 0    Akshay Kumar
# Name: lead, dtype: object
# 62.6750230372527
# 688.0024777222343

# %%
# min/max
subs.max()
# Out:
# 396

# %%
# describe
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# *Series Indexing*

# %%
# integer indexing
x = pd.Series([11,72,63,34,45,56,90])
x[4]
# Out:
# 45

# %%
# negative indexing
x[-3]
# series works in positive indexing not in negative indexing
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     390                 try:
# --> 391                     return self._range.index(new_key)
#     392                 except ValueError as err:
#
# ValueError: -3 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-1920606b8a77> in <cell line: 2>()
#       1 # negative indexing
# ----> 2 x[-3]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     979
#     980         elif key_is_scalar:
# --> 981             return self._get_value(key)
#     982
#     983         if is_hashable(key):
#
# ...

# %%
# slicing
vk[5:16]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
vk[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movies[::2]
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: object

# %%
# fancy indexing
vk[[1,3,4,6,7,8]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 6     9
# 7    34
# 8     0
# Name: runs, dtype: int64

# %%
#indexing with labels -> fancy indexing
movies['Awara Paagal Deewana']
# Out:
# 'Akshay Kumar'

# %% [markdown]
# *Editing Series*

# %%
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi       37
# dtype: int64

# %%
# using indexing
marks_series[1] = 100

# %%
# what if an index does not exist
marks_series['sst'] = 90
# will a new items

# %%
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi       37
# sst         90
# dtype: int64

# %%
# slicing
marks_series[2:4] = [100,100]
marks_series
# Out:
# maths       67
# english    100
# science    100
# hindi      100
# sst         90
# dtype: int64

# %%
# using index label
movies['Uri: The Surgical Strike'] = 'Yami Gautam'
movies
# Out:
# movie
# Uri: The Surgical Strike                     Yami Gautam
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# **Series with Python Functionalities**

# %%
# len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
# type conversion
list(marks_series)
# Out:
# [67, 100, 100, 100, 90]

# %%
dict(marks_series)
# Out:
# {'maths': 67, 'english': 100, 'science': 100, 'hindi': 100, 'sst': 90}

# %%
# membership operator

'Why Cheat India' in movies
# only in index
# Out:
# True

# %%
# for in values
'Yami Gautam' in movies.values
# Out:
# True

# %%
# loops
for i in movies :
  print(i)
# Out:
# Yami Gautam
# Vicky Ahuja
# Anupam Kher
# Emraan Hashmi
# Mona Ambegaonkar
# Geetika Vidya Ohlyan
# Arshad Warsi
# Radhika Apte
# Kangana Ranaut
# Nawazuddin Siddiqui
# Ali Asgar
# Ranveer Singh
# Prit Kamani
# Ajay Devgn
# Sushant Singh Rajput
# Amitabh Bachchan
# Abhimanyu Dasani
# Talha Arshad Reshi
# Nawazuddin Siddiqui
# Garima Agarwal
# Rasika Agashe
# Barun Sobti
# Akshay Kumar
# Zaheer Iqbal
# Vidyut Jammwal
# Deepika Amin
# Manav Kaul
# Naseeruddin Shah
# Varun Dhawan
# Shreyas Talpade
# Tiger Shroff
# Boman Irani
# Ajay Devgn
# Arjun Kapoor
# Gavie Chahal
# Prabhu Deva
# Shahid Kapoor
# Ayushmann Khurrana
# Anupam Kher
# Karanvir Bohra
# Hrithik Roshan
# Jimmy Sheirgill
# John Abraham
# Rishi Kapoor
# Kangana Ranaut
# Natalia Janoszek
# Diljit Dosanjh
# Sidharth Malhotra
# Rajeev Khandelwal
# Zaira Wasim
# Akshay Kumar
# Jacqueline Fernandez
# Ayushmann Khurrana
# Akshaye Khanna
# Sonam Kapoor
# Karan Deol
# Sanjay Dutt
# Bhavesh Kumar
# Sanaya Irani
# Ayushmann Khurrana
# ...

# %%
for i in movies.index:
  print(i)
# in index
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
# Arthmetic Operators(Broadcasting)
100 - marks_series
# Out:
# maths      33
# english     0
# science     0
# hindi       0
# sst        10
# dtype: int64

# %%
# Relational operators
vk >= 50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %%
# Find no of 50's and 100's scores by kohli
vk[vk >= 50].size
# Out:
# 50

# %%
# Find no of duck
vk[vk == 0].size
# Out:
# 9

# %%
# Count number of day when campusx had more than 200 subs a day
subs[subs > 200].size
# Out:
# 59

# %%
# find actors who have done more than 20 movies
num_movies = movies.value_counts()
num_movies[num_movies > 20]
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: lead, dtype: int64

# %% [markdown]
# **Plotting Graphs on Series**

# %%
subs.plot()
# Out:
# <Axes: >

# %%
# top 20 actors with most no of movies
movies.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='pie')
# in pie chat
# Out:
# <Axes: ylabel='lead'>
